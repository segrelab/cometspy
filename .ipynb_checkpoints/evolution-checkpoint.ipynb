# %% [markdown]
# # Evo-COMETS (BETA)
#
# This notebook shows an example of a evo-COMETS simulation, without really any meaningful result.

# %%
import comets as c
import os
import pandas as pd

# %% [markdown]
# We first use the `params` class to load some parameters files.
#
# Note that if we had initialized the object without arguments, it would have returned al parameters set to their default value.

# %%
# .. load parameters and layout from file
my_params = c.params('test_evolution/global_params', 'evolution/package_params')
my_layout = c.layout('test_evolution/layout_blueprint')

# create comets object from the loaded parameters and layout 
my_comets = c.comets(my_layout, my_params)

# run comets simulation
my_comets.run()
# Out:
# Running COMETS simulation ...
# Done!

# %%
my_comets.evolution
# Out:
#     Cycle  x  y                               species       biomass
# 0       0  0  0                   UiJO1366_nonTrimmed  1.000000e-07
# 1       1  0  0                   UiJO1366_nonTrimmed  1.017305e-07
# 2       2  0  0                   UiJO1366_nonTrimmed  1.034909e-07
# 3       3  0  0                   UiJO1366_nonTrimmed  1.052716e-07
# 4       3  0  0  b2e822df-070d-4dbb-b2be-829224439b98  1.017302e-11
# 5       4  0  0                   UiJO1366_nonTrimmed  1.070933e-07
# 6       4  0  0  b2e822df-070d-4dbb-b2be-829224439b98  1.034904e-11
# 7       5  0  0                   UiJO1366_nonTrimmed  1.089465e-07
# 8       5  0  0  b2e822df-070d-4dbb-b2be-829224439b98  1.052810e-11
# 9       6  0  0                   UiJO1366_nonTrimmed  1.108317e-07
# 10      6  0  0  b2e822df-070d-4dbb-b2be-829224439b98  1.071026e-11
# 11      7  0  0                   UiJO1366_nonTrimmed  1.127496e-07
# 12      7  0  0  b2e822df-070d-4dbb-b2be-829224439b98  1.089557e-11
# ...

# %%
my_comets.genotypes
# Out:
#               Ancestor  Mutation                               Species
# 0          NO_ANCESTOR    NO_MUT                   UiJO1366_nonTrimmed
# 1  UiJO1366_nonTrimmed  add_3829  b2e822df-070d-4dbb-b2be-829224439b98
# 2  UiJO1366_nonTrimmed  del_2538  735338cf-9481-480b-8ffd-472cce11e7ba
# 3  UiJO1366_nonTrimmed  del_1657  1bad4e02-6b3c-4084-a083-1cefba9c9642
